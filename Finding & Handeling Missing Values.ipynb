# %% [markdown]
# # Working with Missing Data
# Missing Data can occur when no information is provided for one or more items or for a whole unit. Missing Data is a very big problem in a real-life scenarios. Missing Data can also refer to as NA(Not Available) values in pandas. In DataFrame sometimes many datasets simply arrive with missing data, either because it exists and was not collected or it never existed.

# %%
#Install the below libaries before importing
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

df = pd.read_csv('Travel.csv')
df.head(5)
# Out:
#    CustomerID  ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 0      200000          1  41.0     Self Enquiry         3              6.0
# 1      200001          0  49.0  Company Invited         1             14.0
# 2      200002          1  37.0     Self Enquiry         1              8.0
# 3      200003          0  33.0  Company Invited         1              9.0
# 4      200004          0   NaN     Self Enquiry         1              8.0
#
#        Occupation  Gender  NumberOfPersonVisiting  NumberOfFollowups  \
# 0        Salaried  Female                       3                3.0
# 1        Salaried    Male                       3                4.0
# 2     Free Lancer    Male                       3                4.0
# 3        Salaried  Female                       2                3.0
# 4  Small Business    Male                       2                3.0
#
#   ProductPitched  PreferredPropertyStar MaritalStatus  NumberOfTrips  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4888 entries, 0 to 4887
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CustomerID                4888 non-null   int64
#  1   ProdTaken                 4888 non-null   int64
#  2   Age                       4662 non-null   float64
#  3   TypeofContact             4863 non-null   object
#  4   CityTier                  4888 non-null   int64
#  5   DurationOfPitch           4637 non-null   float64
#  6   Occupation                4888 non-null   object
#  7   Gender                    4888 non-null   object
#  8   NumberOfPersonVisiting    4888 non-null   int64
#  9   NumberOfFollowups         4843 non-null   float64
#  10  ProductPitched            4888 non-null   object
#  11  PreferredPropertyStar     4862 non-null   float64
#  12  MaritalStatus             4888 non-null   object
# ...

# %% [markdown]
# # Finding Missing Values
# - Checking for missing values using isnull() and notnull()
#
# In order to check missing values in Pandas DataFrame, we use a function isnull() and notnull(). Both function help in checking whether a value is NaN or not. These function can also be used in Pandas Series in order to find null values in a series.
#
# - Checking for missing values using isnull()
#
# In order to check null values in Pandas DataFrame, we use isnull() function this function return dataframe of Boolean values which are True for NaN values.

# %%
df.isnull()
# Out:
#       CustomerID  ProdTaken    Age  TypeofContact  CityTier  DurationOfPitch  \
# 0          False      False  False          False     False            False
# 1          False      False  False          False     False            False
# 2          False      False  False          False     False            False
# 3          False      False  False          False     False            False
# 4          False      False   True          False     False            False
# ...          ...        ...    ...            ...       ...              ...
# 4883       False      False  False          False     False            False
# 4884       False      False  False          False     False            False
# 4885       False      False  False          False     False            False
# 4886       False      False  False          False     False            False
# 4887       False      False  False          False     False            False
#
# ...

# %%
df.isnull().sum()
# Out:
# CustomerID                    0
# ProdTaken                     0
# Age                         226
# TypeofContact                25
# CityTier                      0
# DurationOfPitch             251
# Occupation                    0
# Gender                        0
# NumberOfPersonVisiting        0
# NumberOfFollowups            45
# ProductPitched                0
# PreferredPropertyStar        26
# MaritalStatus                 0
# NumberOfTrips               140
# Passport                      0
# PitchSatisfactionScore        0
# OwnCar                        0
# NumberOfChildrenVisiting     66
# Designation                   0
# MonthlyIncome               233
# dtype: int64

# %% [markdown]
# - Checking for missing values using notnull()
#
# In order to check null values in Pandas Dataframe, we use notnull() function this function return dataframe of Boolean values which are False for NaN values.

# %%
df.notnull()
# Out:
#       CustomerID  ProdTaken    Age  TypeofContact  CityTier  DurationOfPitch  \
# 0           True       True   True           True      True             True
# 1           True       True   True           True      True             True
# 2           True       True   True           True      True             True
# 3           True       True   True           True      True             True
# 4           True       True  False           True      True             True
# ...          ...        ...    ...            ...       ...              ...
# 4883        True       True   True           True      True             True
# 4884        True       True   True           True      True             True
# 4885        True       True   True           True      True             True
# 4886        True       True   True           True      True             True
# 4887        True       True   True           True      True             True
#
# ...

# %%
sns.heatmap(df.isnull(), yticklabels=False, cbar=False, cmap='viridis')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Handelling Missing Values

# %% [markdown]
# # 1. Filling missing values with 0

# %%
new_df = df.fillna(0)
new_df.head(5)
# Out:
#    CustomerID  ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 0      200000          1  41.0     Self Enquiry         3              6.0
# 1      200001          0  49.0  Company Invited         1             14.0
# 2      200002          1  37.0     Self Enquiry         1              8.0
# 3      200003          0  33.0  Company Invited         1              9.0
# 4      200004          0   0.0     Self Enquiry         1              8.0
#
#        Occupation  Gender  NumberOfPersonVisiting  NumberOfFollowups  \
# 0        Salaried  Female                       3                3.0
# 1        Salaried    Male                       3                4.0
# 2     Free Lancer    Male                       3                4.0
# 3        Salaried  Female                       2                3.0
# 4  Small Business    Male                       2                3.0
#
#   ProductPitched  PreferredPropertyStar MaritalStatus  NumberOfTrips  \
# ...

# %%
# Again checking for null values
new_df.isnull().sum()
# Out:
# CustomerID                  0
# ProdTaken                   0
# Age                         0
# TypeofContact               0
# CityTier                    0
# DurationOfPitch             0
# Occupation                  0
# Gender                      0
# NumberOfPersonVisiting      0
# NumberOfFollowups           0
# ProductPitched              0
# PreferredPropertyStar       0
# MaritalStatus               0
# NumberOfTrips               0
# Passport                    0
# PitchSatisfactionScore      0
# OwnCar                      0
# NumberOfChildrenVisiting    0
# Designation                 0
# MonthlyIncome               0
# dtype: int64

# %% [markdown]
# # 2. Filling NaN values with forward fill value
# If we use forward fill that simply means we are forwarding the previous value where ever we have NaN values.

# %%
ffill_df = df.fillna(method="ffill")
ffill_df.head(5)
# Out:
#    CustomerID  ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 0      200000          1  41.0     Self Enquiry         3              6.0
# 1      200001          0  49.0  Company Invited         1             14.0
# 2      200002          1  37.0     Self Enquiry         1              8.0
# 3      200003          0  33.0  Company Invited         1              9.0
# 4      200004          0  33.0     Self Enquiry         1              8.0
#
#        Occupation  Gender  NumberOfPersonVisiting  NumberOfFollowups  \
# 0        Salaried  Female                       3                3.0
# 1        Salaried    Male                       3                4.0
# 2     Free Lancer    Male                       3                4.0
# 3        Salaried  Female                       2                3.0
# 4  Small Business    Male                       2                3.0
#
#   ProductPitched  PreferredPropertyStar MaritalStatus  NumberOfTrips  \
# ...

# %% [markdown]
# # 3. Filling NaN values with backward fill value
# If we use backward fill that simply means we are forwarding the value after the NaN value where ever we have NaN values.

# %%
bfill_df = df.fillna(method="bfill")
bfill_df.head(5)
# Out:
#    CustomerID  ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 0      200000          1  41.0     Self Enquiry         3              6.0
# 1      200001          0  49.0  Company Invited         1             14.0
# 2      200002          1  37.0     Self Enquiry         1              8.0
# 3      200003          0  33.0  Company Invited         1              9.0
# 4      200004          0  32.0     Self Enquiry         1              8.0
#
#        Occupation  Gender  NumberOfPersonVisiting  NumberOfFollowups  \
# 0        Salaried  Female                       3                3.0
# 1        Salaried    Male                       3                4.0
# 2     Free Lancer    Male                       3                4.0
# 3        Salaried  Female                       2                3.0
# 4  Small Business    Male                       2                3.0
#
#   ProductPitched  PreferredPropertyStar MaritalStatus  NumberOfTrips  \
# ...

# %%
bfill_df.isnull().sum()
# Out:
# CustomerID                  0
# ProdTaken                   0
# Age                         0
# TypeofContact               0
# CityTier                    0
# DurationOfPitch             0
# Occupation                  0
# Gender                      0
# NumberOfPersonVisiting      0
# NumberOfFollowups           0
# ProductPitched              0
# PreferredPropertyStar       0
# MaritalStatus               0
# NumberOfTrips               0
# Passport                    0
# PitchSatisfactionScore      0
# OwnCar                      0
# NumberOfChildrenVisiting    0
# Designation                 0
# MonthlyIncome               0
# dtype: int64

# %% [markdown]
# # 4. Interpolate of missing values
#
# Interpolation is a statistical method by which related known values are used to estimate an unknown price or potential yield of a security. Interpolation is achieved by using other established values that are located in sequence with the unknown value.

# %% [markdown]
# # 1) Linear Interpolation
# Linear interpolation is basically the estimation of an unknown value that falls within two known values.

# %%
new_df = df.interpolate(method = 'linear') 
new_df.isnull().sum()
# Out:
# CustomerID                   0
# ProdTaken                    0
# Age                          0
# TypeofContact               25
# CityTier                     0
# DurationOfPitch              0
# Occupation                   0
# Gender                       0
# NumberOfPersonVisiting       0
# NumberOfFollowups            0
# ProductPitched               0
# PreferredPropertyStar        0
# MaritalStatus                0
# NumberOfTrips                0
# Passport                     0
# PitchSatisfactionScore       0
# OwnCar                       0
# NumberOfChildrenVisiting     0
# Designation                  0
# MonthlyIncome                0
# dtype: int64

# %% [markdown]
# # 2) Interpolation Through Padding
# Interpolation with help of padding simply means filling missing values with the same value present above them in the dataset. If the missing value is in the first row then this method will not work. While using this technique you also need to specify the limit which means how many NaN values to fill.

# %%
new_df = df.interpolate(method = 'pad', limit = 2) 
new_df.isnull().sum()
# Out:
# CustomerID                  0
# ProdTaken                   0
# Age                         2
# TypeofContact               0
# CityTier                    0
# DurationOfPitch             4
# Occupation                  0
# Gender                      0
# NumberOfPersonVisiting      0
# NumberOfFollowups           0
# ProductPitched              0
# PreferredPropertyStar       0
# MaritalStatus               0
# NumberOfTrips               0
# Passport                    0
# PitchSatisfactionScore      0
# OwnCar                      0
# NumberOfChildrenVisiting    0
# Designation                 0
# MonthlyIncome               4
# dtype: int64

# %% [markdown]
# # 3) Polynomial Interpolation
# In Polynomial Interpolation you need to specify an order. It means that polynomial interpolation is filling missing values with the lowest possible degree that passes through available data points. The polynomial Interpolation curve is like the trigonometric sin curve or assumes it like a parabola shape.

# %%
new_df = df.interpolate(method = 'polynomial', order = 2) 
new_df.isnull().sum()
# Out:
# CustomerID                   0
# ProdTaken                    0
# Age                          0
# TypeofContact               25
# CityTier                     0
# DurationOfPitch              0
# Occupation                   0
# Gender                       0
# NumberOfPersonVisiting       0
# NumberOfFollowups            0
# ProductPitched               0
# PreferredPropertyStar        0
# MaritalStatus                0
# NumberOfTrips                0
# Passport                     0
# PitchSatisfactionScore       0
# OwnCar                       0
# NumberOfChildrenVisiting     0
# Designation                  0
# MonthlyIncome                0
# dtype: int64

# %% [markdown]
# # 5. Simple Imputation
# This method involves utilizing a numerical summary of the variable where the missing value occurred (that is using the feature or variable's central tendency summary, such as mean, median, and mode).
#
# When you use this strategy to fill in the missing values, you need to evaluate the variable's distribution to determine which central tendency summary to apply.
#
# You use this method in the MCAR category. And you implement it in Python using the SimpleImputer transformer in the Scikit-learn library.

# %%
# Replacing nan values with median in AGe column
from sklearn.impute import SimpleImputer
#Specify the strategy to be the median class
fea_transformer = SimpleImputer(strategy="median")
values = fea_transformer.fit_transform(df[['Age']])
#pd.DataFrame(values)

# %%
# Replacing the column values with new values
df.Age= values
df.isnull().sum()
# Out:
# CustomerID                    0
# ProdTaken                     0
# Age                           0
# TypeofContact                25
# CityTier                      0
# DurationOfPitch               0
# Occupation                    0
# Gender                        0
# NumberOfPersonVisiting        0
# NumberOfFollowups            45
# ProductPitched                0
# PreferredPropertyStar        26
# MaritalStatus                 0
# NumberOfTrips               140
# Passport                      0
# PitchSatisfactionScore        0
# OwnCar                        0
# NumberOfChildrenVisiting     66
# Designation                   0
# MonthlyIncome               233
# dtype: int64

# %% [markdown]
# Now we can see that, there are no nan values in Age column.

# %%
# Replacing nan values with most_frequent values in TypeofContact column
from sklearn.impute import SimpleImputer
#Specify the strategy to be the median class
fea_transformer = SimpleImputer(strategy="most_frequent")
values = fea_transformer.fit_transform(df[["TypeofContact"]])

# %%
# Replacing the column values with new values
df.TypeofContact= values
df.isnull().sum()
# Out:
# CustomerID                    0
# ProdTaken                     0
# Age                           0
# TypeofContact                 0
# CityTier                      0
# DurationOfPitch               0
# Occupation                    0
# Gender                        0
# NumberOfPersonVisiting        0
# NumberOfFollowups            45
# ProductPitched                0
# PreferredPropertyStar        26
# MaritalStatus                 0
# NumberOfTrips               140
# Passport                      0
# PitchSatisfactionScore        0
# OwnCar                        0
# NumberOfChildrenVisiting     66
# Designation                   0
# MonthlyIncome               233
# dtype: int64

# %%
# Replacing nan values with mean values in DurationOfPitch column
from sklearn.impute import SimpleImputer
#Specify the strategy to be the median class
fea_transformer = SimpleImputer(strategy="mean")
values = fea_transformer.fit_transform(df[["DurationOfPitch"]])

# %%
# Replacing the column values with new values
df.DurationOfPitch= values
df.isnull().sum()
# Out:
# CustomerID                    0
# ProdTaken                     0
# Age                           0
# TypeofContact                 0
# CityTier                      0
# DurationOfPitch               0
# Occupation                    0
# Gender                        0
# NumberOfPersonVisiting        0
# NumberOfFollowups            45
# ProductPitched                0
# PreferredPropertyStar        26
# MaritalStatus                 0
# NumberOfTrips               140
# Passport                      0
# PitchSatisfactionScore        0
# OwnCar                        0
# NumberOfChildrenVisiting     66
# Designation                   0
# MonthlyIncome               233
# dtype: int64

# %%
# Replacing nan values with mean values in NumberOfFollowups column
from sklearn.impute import SimpleImputer
#Specify the strategy to be the median class
fea_transformer = SimpleImputer(strategy="mean")
values = fea_transformer.fit_transform(df[["NumberOfFollowups"]])

# %%
# Replacing the column values with new values
df.NumberOfFollowups= values
df.isnull().sum()
# Out:
# CustomerID                    0
# ProdTaken                     0
# Age                           0
# TypeofContact                 0
# CityTier                      0
# DurationOfPitch               0
# Occupation                    0
# Gender                        0
# NumberOfPersonVisiting        0
# NumberOfFollowups             0
# ProductPitched                0
# PreferredPropertyStar        26
# MaritalStatus                 0
# NumberOfTrips               140
# Passport                      0
# PitchSatisfactionScore        0
# OwnCar                        0
# NumberOfChildrenVisiting     66
# Designation                   0
# MonthlyIncome               233
# dtype: int64

# %%
# Replacing nan values with mean values in PreferredPropertyStar column
from sklearn.impute import SimpleImputer
#Specify the strategy to be the median class
fea_transformer = SimpleImputer(strategy="mean")
values_PreferredPropertyStar = fea_transformer.fit_transform(df[["PreferredPropertyStar"]])
# Replacing the column values with new values
df.PreferredPropertyStar= values


# Replacing nan values with mean values in NumberOfTrips column
from sklearn.impute import SimpleImputer
#Specify the strategy to be the median class
fea_transformer = SimpleImputer(strategy="mean")
values_NumberOfTrips = fea_transformer.fit_transform(df[["NumberOfTrips"]])
# Replacing the column values with new values
df.NumberOfTrips= values


# Replacing nan values with mean values in NumberOfChildrenVisiting column
from sklearn.impute import SimpleImputer
#Specify the strategy to be the median class
fea_transformer = SimpleImputer(strategy="mean")
values_NumberOfChildrenVisiting = fea_transformer.fit_transform(df[["NumberOfChildrenVisiting"]])
# Replacing the column values with new values
df.NumberOfChildrenVisiting= values


# Replacing nan values with mean values in MonthlyIncome column
from sklearn.impute import SimpleImputer
#Specify the strategy to be the median class
fea_transformer = SimpleImputer(strategy="mean")
values_MonthlyIncome = fea_transformer.fit_transform(df[["MonthlyIncome"]])
# Replacing the column values with new values
df.MonthlyIncome= values

# %%
df.isnull().sum()
# Out:
# CustomerID                  0
# ProdTaken                   0
# Age                         0
# TypeofContact               0
# CityTier                    0
# DurationOfPitch             0
# Occupation                  0
# Gender                      0
# NumberOfPersonVisiting      0
# NumberOfFollowups           0
# ProductPitched              0
# PreferredPropertyStar       0
# MaritalStatus               0
# NumberOfTrips               0
# Passport                    0
# PitchSatisfactionScore      0
# OwnCar                      0
# NumberOfChildrenVisiting    0
# Designation                 0
# MonthlyIncome               0
# dtype: int64

# %% [markdown]
# Now we have cleared null values from all the columns

# %% [markdown]
# # 6. Droping Null Values

# %%
df = pd.read_csv('Travel.csv')
df
# Out:
#       CustomerID  ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 0         200000          1  41.0     Self Enquiry         3              6.0
# 1         200001          0  49.0  Company Invited         1             14.0
# 2         200002          1  37.0     Self Enquiry         1              8.0
# 3         200003          0  33.0  Company Invited         1              9.0
# 4         200004          0   NaN     Self Enquiry         1              8.0
# ...          ...        ...   ...              ...       ...              ...
# 4883      204883          1  49.0     Self Enquiry         3              9.0
# 4884      204884          1  28.0  Company Invited         1             31.0
# 4885      204885          1  52.0     Self Enquiry         3             17.0
# 4886      204886          1  19.0     Self Enquiry         3             16.0
# 4887      204887          1  36.0     Self Enquiry         1             14.0
#
# ...

# %%
#Droping null values
df = df.dropna()
df
# Out:
#       CustomerID  ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 0         200000          1  41.0     Self Enquiry         3              6.0
# 1         200001          0  49.0  Company Invited         1             14.0
# 2         200002          1  37.0     Self Enquiry         1              8.0
# 3         200003          0  33.0  Company Invited         1              9.0
# 5         200005          0  32.0  Company Invited         1              8.0
# ...          ...        ...   ...              ...       ...              ...
# 4883      204883          1  49.0     Self Enquiry         3              9.0
# 4884      204884          1  28.0  Company Invited         1             31.0
# 4885      204885          1  52.0     Self Enquiry         3             17.0
# 4886      204886          1  19.0     Self Enquiry         3             16.0
# 4887      204887          1  36.0     Self Enquiry         1             14.0
#
# ...

# %% [markdown]
# You can see the count of data after dropinh the records containing nan values

# %% [markdown]
# # 7. Assigning An Unique Category
# A categorical feature will have a definite number of possibilities, such as gender, for example. Since they have a definite number of classes, we can assign another class for the missing values.

# %%
df = pd.read_csv('Travel.csv')
print('count of Nan values in TypeofContact column is',df['TypeofContact'].isnull().sum())
# Out:
# count of Nan values in TypeofContact column is 25

# %%
# Now let us see how many categories of values we have in TypeofContact column 
print(df['TypeofContact'].value_counts())
# Out:
# Self Enquiry       3444
# Company Invited    1419
# Name: TypeofContact, dtype: int64

# %%
# let's add another unique categoty
df['TypeofContact'] = df['TypeofContact'].fillna('Other')

# Now let's check the unique value count of TypeofContact column again
print('count of Nan values in TypeofContact column is',df['TypeofContact'].isnull().sum())
# Out:
# count of Nan values in TypeofContact column is 0

# %% [markdown]
# # 8. Imputation using the KNNimputer()
# KNNimputer is a scikit-learn class used to fill out or predict the missing values in a dataset. It is a more useful method which works on the basic approach of the KNN algorithm rather than the naive approach of filling all the values with mean or the median. In this approach, we specify a distance from the missing values which is also known as the K parameter. The missing value will be predicted in reference to the mean of the neighbours.

# %%
from sklearn.impute import KNNImputer

df = pd.read_csv("Products_Data.csv")
del df['Date']
imputer = KNNImputer(n_neighbors=2)
df_filled = imputer.fit_transform(df)
df_filled
# Out:
# array([[6.58663892e+08, 3.16000000e+01, 3.59461549e+02, ...,
#         3.30000000e+01, 1.72594772e+08, 4.99079647e+08],
#        [6.71827495e+08, 2.61000000e+01, 3.60208734e+02, ...,
#         3.60000000e+01, 3.98894101e+08, 2.77197595e+08],
#        [6.77114763e+08, 2.82000000e+01, 3.60036253e+02, ...,
#         3.00000000e+01, 1.70024474e+08, 4.59695801e+08],
#        ...,
#        [2.03888164e+09, 5.44000000e+01, 4.17608465e+02, ...,
#         3.80000000e+01, 6.78076859e+08, 1.58217934e+09],
#        [2.26025620e+09, 5.78000000e+01, 4.17356792e+02, ...,
#         3.90000000e+01, 1.29219728e+09, 4.08062301e+08],
#        [1.59255828e+09, 4.55000000e+01, 4.17632957e+02, ...,
#         2.30000000e+01, 9.04089657e+08, 6.28265694e+08]])
